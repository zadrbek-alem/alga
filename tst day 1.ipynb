# %%
import numpy as np
import pandas as pd
trainsz = 2245
testsz = 2243
path_train_x = '/kaggle/input/up-solving-tst-day-1/train/train/filtered_images/'
path_train_y = '/kaggle/input/up-solving-tst-day-1/train/train/real_images/'
path_test_x = '/kaggle/input/up-solving-tst-day-1/test/test/filtered_images/'

# %%
def generate_samples(original_img, distorted_img, window=3):
    H, W, _ = original_img.shape
    pad = window // 2
    X = []
    Y = []
    for i in range(pad, H - pad):
        for j in range(pad, W - pad):
            patch = distorted_img[i-pad:i+pad+1, j-pad:j+pad+1, :].flatten()
            target = original_img[i, j, :]  # Истинные RGB значения
            X.append(patch)
            Y.append(target)
    return np.array(X), np.array(Y)

# %%
from PIL import Image
train_images_x = np.zeros((trainsz, 128, 128, 3))
for i in range(trainsz):
    train_images_x[i] = np.array(Image.open(path_train_x + str(i) + ".png"))
    if (i + 1) % (trainsz // 100) == 0:
        print("trainx preprocess " + str((i + 1) / (trainsz // 100)))
train_images_y = np.zeros((trainsz, 128, 128, 3))
for i in range(trainsz):
    train_images_y[i] = np.array(Image.open(path_train_y + str(i) + ".png"))
    if (i + 1) % (trainsz // 100) == 0:
        print("trainy preprocess " + str((i + 1) / (trainsz // 100)))
test_images_x = np.zeros((testsz, 128, 128, 3))
for i in range(testsz):
    test_images_x[i] = np.array(Image.open(path_test_x + str(i) + ".png"))
    if (i + 1) % (testsz // 100) == 0:
        print("test preprocess " + str((i + 1) / (testsz // 100)))
# Out:
# trainx preprocess 1.0
# trainx preprocess 2.0
# trainx preprocess 3.0
# trainx preprocess 4.0
# trainx preprocess 5.0
# trainx preprocess 6.0
# trainx preprocess 7.0
# trainx preprocess 8.0
# trainx preprocess 9.0
# trainx preprocess 10.0
# trainx preprocess 11.0
# trainx preprocess 12.0
# trainx preprocess 13.0
# trainx preprocess 14.0
# trainx preprocess 15.0
# trainx preprocess 16.0
# trainx preprocess 17.0
# trainx preprocess 18.0
# trainx preprocess 19.0
# trainx preprocess 20.0
# trainx preprocess 21.0
# trainx preprocess 22.0
# trainx preprocess 23.0
# trainx preprocess 24.0
# trainx preprocess 25.0
# trainx preprocess 26.0
# trainx preprocess 27.0
# trainx preprocess 28.0
# trainx preprocess 29.0
# trainx preprocess 30.0
# trainx preprocess 31.0
# trainx preprocess 32.0
# trainx preprocess 33.0
# trainx preprocess 34.0
# trainx preprocess 35.0
# trainx preprocess 36.0
# trainx preprocess 37.0
# trainx preprocess 38.0
# trainx preprocess 39.0
# trainx preprocess 40.0
# trainx preprocess 41.0
# trainx preprocess 42.0
# trainx preprocess 43.0
# trainx preprocess 44.0
# trainx preprocess 45.0
# trainx preprocess 46.0
# trainx preprocess 47.0
# trainx preprocess 48.0
# trainx preprocess 49.0
# trainx preprocess 50.0
# trainx preprocess 51.0
# trainx preprocess 52.0
# trainx preprocess 53.0
# trainx preprocess 54.0
# trainx preprocess 55.0
# trainx preprocess 56.0
# trainx preprocess 57.0
# trainx preprocess 58.0
# trainx preprocess 59.0
# trainx preprocess 60.0
# trainx preprocess 61.0
# trainx preprocess 62.0
# trainx preprocess 63.0
# trainx preprocess 64.0
# trainx preprocess 65.0
# trainx preprocess 66.0
# trainx preprocess 67.0
# trainx preprocess 68.0
# trainx preprocess 69.0
# trainx preprocess 70.0
# trainx preprocess 71.0
# trainx preprocess 72.0
# trainx preprocess 73.0
# trainx preprocess 74.0
# trainx preprocess 75.0
# trainx preprocess 76.0
# trainx preprocess 77.0
# trainx preprocess 78.0
# trainx preprocess 79.0
# trainx preprocess 80.0
# trainx preprocess 81.0
# trainx preprocess 82.0
# trainx preprocess 83.0
# trainx preprocess 84.0
# trainx preprocess 85.0
# trainx preprocess 86.0
# trainx preprocess 87.0
# trainx preprocess 88.0
# trainx preprocess 89.0
# trainx preprocess 90.0
# trainx preprocess 91.0
# trainx preprocess 92.0
# trainx preprocess 93.0
# trainx preprocess 94.0
# trainx preprocess 95.0
# trainx preprocess 96.0
# trainx preprocess 97.0
# trainx preprocess 98.0
# trainx preprocess 99.0
# trainx preprocess 100.0
# trainx preprocess 101.0
# trainx preprocess 102.0
# trainy preprocess 1.0
# trainy preprocess 2.0
# trainy preprocess 3.0
# trainy preprocess 4.0
# trainy preprocess 5.0
# trainy preprocess 6.0
# trainy preprocess 7.0
# trainy preprocess 8.0
# trainy preprocess 9.0
# trainy preprocess 10.0
# trainy preprocess 11.0
# trainy preprocess 12.0
# trainy preprocess 13.0
# trainy preprocess 14.0
# trainy preprocess 15.0
# trainy preprocess 16.0
# trainy preprocess 17.0
# trainy preprocess 18.0
# trainy preprocess 19.0
# trainy preprocess 20.0
# trainy preprocess 21.0
# trainy preprocess 22.0
# trainy preprocess 23.0
# trainy preprocess 24.0
# trainy preprocess 25.0
# trainy preprocess 26.0
# trainy preprocess 27.0
# trainy preprocess 28.0
# trainy preprocess 29.0
# trainy preprocess 30.0
# trainy preprocess 31.0
# trainy preprocess 32.0
# trainy preprocess 33.0
# trainy preprocess 34.0
# trainy preprocess 35.0
# trainy preprocess 36.0
# trainy preprocess 37.0
# trainy preprocess 38.0
# trainy preprocess 39.0
# trainy preprocess 40.0
# trainy preprocess 41.0
# trainy preprocess 42.0
# trainy preprocess 43.0
# trainy preprocess 44.0
# trainy preprocess 45.0
# trainy preprocess 46.0
# trainy preprocess 47.0
# trainy preprocess 48.0
# trainy preprocess 49.0
# trainy preprocess 50.0
# trainy preprocess 51.0
# trainy preprocess 52.0
# trainy preprocess 53.0
# trainy preprocess 54.0
# trainy preprocess 55.0
# trainy preprocess 56.0
# trainy preprocess 57.0
# trainy preprocess 58.0
# trainy preprocess 59.0
# trainy preprocess 60.0
# trainy preprocess 61.0
# trainy preprocess 62.0
# trainy preprocess 63.0
# trainy preprocess 64.0
# trainy preprocess 65.0
# trainy preprocess 66.0
# trainy preprocess 67.0
# trainy preprocess 68.0
# trainy preprocess 69.0
# trainy preprocess 70.0
# trainy preprocess 71.0
# trainy preprocess 72.0
# trainy preprocess 73.0
# trainy preprocess 74.0
# trainy preprocess 75.0
# trainy preprocess 76.0
# trainy preprocess 77.0
# trainy preprocess 78.0
# trainy preprocess 79.0
# trainy preprocess 80.0
# trainy preprocess 81.0
# trainy preprocess 82.0
# trainy preprocess 83.0
# trainy preprocess 84.0
# trainy preprocess 85.0
# trainy preprocess 86.0
# trainy preprocess 87.0
# trainy preprocess 88.0
# trainy preprocess 89.0
# trainy preprocess 90.0
# trainy preprocess 91.0
# trainy preprocess 92.0
# trainy preprocess 93.0
# trainy preprocess 94.0
# trainy preprocess 95.0
# trainy preprocess 96.0
# trainy preprocess 97.0
# trainy preprocess 98.0
# trainy preprocess 99.0
# trainy preprocess 100.0
# trainy preprocess 101.0
# trainy preprocess 102.0
# test preprocess 1.0
# test preprocess 2.0
# test preprocess 3.0
# test preprocess 4.0
# test preprocess 5.0
# test preprocess 6.0
# test preprocess 7.0
# test preprocess 8.0
# test preprocess 9.0
# test preprocess 10.0
# test preprocess 11.0
# test preprocess 12.0
# test preprocess 13.0
# test preprocess 14.0
# test preprocess 15.0
# test preprocess 16.0
# test preprocess 17.0
# test preprocess 18.0
# test preprocess 19.0
# test preprocess 20.0
# test preprocess 21.0
# test preprocess 22.0
# test preprocess 23.0
# test preprocess 24.0
# test preprocess 25.0
# test preprocess 26.0
# test preprocess 27.0
# test preprocess 28.0
# test preprocess 29.0
# test preprocess 30.0
# test preprocess 31.0
# test preprocess 32.0
# test preprocess 33.0
# test preprocess 34.0
# test preprocess 35.0
# test preprocess 36.0
# test preprocess 37.0
# test preprocess 38.0
# test preprocess 39.0
# test preprocess 40.0
# test preprocess 41.0
# test preprocess 42.0
# test preprocess 43.0
# test preprocess 44.0
# test preprocess 45.0
# test preprocess 46.0
# test preprocess 47.0
# test preprocess 48.0
# test preprocess 49.0
# test preprocess 50.0
# test preprocess 51.0
# test preprocess 52.0
# test preprocess 53.0
# test preprocess 54.0
# test preprocess 55.0
# test preprocess 56.0
# test preprocess 57.0
# test preprocess 58.0
# test preprocess 59.0
# test preprocess 60.0
# test preprocess 61.0
# test preprocess 62.0
# test preprocess 63.0
# test preprocess 64.0
# test preprocess 65.0
# test preprocess 66.0
# test preprocess 67.0
# test preprocess 68.0
# test preprocess 69.0
# test preprocess 70.0
# test preprocess 71.0
# test preprocess 72.0
# test preprocess 73.0
# test preprocess 74.0
# test preprocess 75.0
# test preprocess 76.0
# test preprocess 77.0
# test preprocess 78.0
# test preprocess 79.0
# test preprocess 80.0
# test preprocess 81.0
# test preprocess 82.0
# test preprocess 83.0
# test preprocess 84.0
# test preprocess 85.0
# test preprocess 86.0
# test preprocess 87.0
# test preprocess 88.0
# test preprocess 89.0
# test preprocess 90.0
# test preprocess 91.0
# test preprocess 92.0
# test preprocess 93.0
# test preprocess 94.0
# test preprocess 95.0
# test preprocess 96.0
# test preprocess 97.0
# test preprocess 98.0
# test preprocess 99.0
# test preprocess 100.0
# test preprocess 101.0

# %%
import numpy as np
from numpy.lib.stride_tricks import sliding_window_view
from skimage.color import rgb2hsv, rgb2lab
from skimage.filters import sobel
from tqdm import tqdm

def extract_enhanced_features(imgs_x, imgs_y, patch_size=5, samples_per_image=1000):
    pad = patch_size // 2
    features = []
    targets = []
    
    for i in tqdm(range(imgs_x.shape[0]), desc="Extracting enhanced patches"):
        img_x = np.pad(imgs_x[i], ((pad, pad), (pad, pad), (0, 0)), mode='reflect')
        img_y = np.pad(imgs_y[i], ((pad, pad), (pad, pad), (0, 0)), mode='reflect')

        windows_x = sliding_window_view(img_x, (patch_size, patch_size, 3))
        windows_y = sliding_window_view(img_y, (patch_size, patch_size, 3))

        H, W = windows_x.shape[:2]
        for _ in range(samples_per_image):
            y = np.random.randint(0, H)
            x = np.random.randint(0, W)
            patch_x = windows_x[y, x]
            target = img_y[y+pad, x+pad]  # центр патча

            hsv = rgb2hsv(patch_x)
            lab = rgb2lab(patch_x)
            gray = np.mean(patch_x, axis=2)
            sobel_edge = sobel(gray)

            feats = np.concatenate([
                patch_x.reshape(-1),
                hsv.reshape(-1),
                lab.reshape(-1),
                [np.mean(gray), np.std(gray), np.mean(sobel_edge)],
                [x / W, y / H]
            ])

            features.append(feats)
            targets.append(target)

    return np.array(features), np.array(targets)

# %%
from sklearn.linear_model import Ridge
from xgboost import XGBRegressor
def train_ridge_models(X, Y, alpha=1.0):
    models = []
    for c in range(3):
        model = XGBRegressor()
        model.fit(X, Y[:, c])
        models.append(model)
    return models

# %%
from skimage.color import rgb2hsv, rgb2lab
from skimage.filters import sobel

def predict_images_fast(imgs_x, models, patch_size=5):
    pad = patch_size // 2
    pred_images = np.zeros_like(imgs_x)

    for idx in range(imgs_x.shape[0]):
        img = np.pad(imgs_x[idx], ((pad, pad), (pad, pad), (0, 0)), mode='reflect').astype(float)
        pred = np.zeros((128 * 128, 3))
        count = 0
        for i in range(pad, 128 + pad):
            for j in range(pad, 128 + pad):
                patch = img[i - pad:i + pad + 1, j - pad:j + pad + 1, :]

                hsv = rgb2hsv(patch)
                lab = rgb2lab(patch)
                gray = np.mean(patch, axis=2)
                sobel_edge = sobel(gray)

                feat = np.concatenate([
                    patch.reshape(-1),
                    hsv.reshape(-1),
                    lab.reshape(-1),
                    [np.mean(gray), np.std(gray), np.mean(sobel_edge)],
                    [j / 128, i / 128]  # нормированные координаты
                ])

                pred[count] = [model.predict(feat.reshape(1, -1))[0] for model in models]
                count += 1

        pred_images[idx] = pred.reshape(128, 128, 3)

    return np.clip(pred_images, 0, 255).astype(np.uint8)

# %%
# Параметры
patch_size = 5
samples_per_image = 3  # вместо ~16 тыс. пикселей
print("sampling")
# Сэмплирование и обучение
X_train, Y_train = extract_enhanced_features(train_images_x, train_images_y, patch_size, samples_per_image)
models = train_ridge_models(X_train, Y_train, alpha=1.0)
print("predicting")
# Предсказание
test_pred_y = predict_images_fast(test_images_x, models, patch_size=patch_size)
# Out:
# sampling
# Extracting enhanced patches: 100%|██████████| 2245/2245 [00:05<00:00, 383.24it/s]
# predicting

# %%
test_pred_y.shape

# %%
sub = pd.read_csv('/kaggle/input/tst-day-1/sample_submission.csv')
sub

# %%
import pandas as pd
import numpy as np

# Предполагаем, что test_pred_y.shape == (2243, 128, 128, 3)

# 1. Меняем порядок каналов с RGB на BGR
test_pred_y_bgr = test_pred_y[..., ::-1]  # меняем местами каналы по последней оси

# 2. Векторизуем пиксели
flat_pixels = test_pred_y_bgr.reshape(test_pred_y_bgr.shape[0], -1)

# 3. Создаём DataFrame с колонками pixel0, pixel1, ...
pixel_cols = ['pixel' + str(i) for i in range(flat_pixels.shape[1])]
sub = pd.DataFrame(flat_pixels, columns=pixel_cols)

# 4. Добавляем колонку 'id' в начало с нужным диапазоном
ids = np.arange(0, 0 + test_pred_y.shape[0])
sub.insert(0, 'id', ids)

# Проверяем
print(sub.head())
print(sub.shape)  # (2243, 1 + 128*128*3)

# %%
sub.to_csv('submission.csv', index=False)
#🙂
